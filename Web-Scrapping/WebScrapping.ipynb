# %%
# !pip install pandas
import pandas as pd
import requests
from bs4 import BeautifulSoup
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
url = 'https://editorial.rottentomatoes.com/guide/best-movies-of-all-time/'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="hitim" lang="en-US">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <!-- OneTrust Cookies Consent Notice start for rottentomatoes.com -->
# <script charset="UTF-8" crossorigin="anonymous" data-domain-script="7e979733-6841-4fce-9182-515fac69187f" integrity="sha384-TKdmlzVmoD70HzftTw4WtOzIBL5mNx8mXSRzEvwrWjpIJ7FZ/EuX758yMDWXtRUN" src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js" type="text/javascript">
# </script>
# <script type="text/javascript">
# 		function OptanonWrapper() { }
# 	</script>
# <!-- OneTrust Cookies Consent Notice end for rottentomatoes.com -->
# <!-- OneTrust IAB US Privacy (USP) -->
# <script ccpa-opt-out-geo="US" ccpa-opt-out-ids="USP" ccpa-opt-out-lspa="false" charset="UTF-8" src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js" type="text/javascript">
# </script>
# ...

# %%
movie_name = []
year = []
rating = []
critics_consensus = []
synopsis = []
director_list = [] #list for director

# %%
movie_data = soup.findAll('div', attrs= {'class': 'row countdown-item'})

# %%
movie_data
# Out:
# [<div class="row countdown-item" id="row-index-1" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#1</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/la_confidential">
#  <div><img alt="" class="article_poster" src="https://resizing.flixster.com/AsFK_hZjOw2jT1elg7vvFuhXzg8=/fit-in/180x240/v2/https://resizing.flixster.com/-XZAfHZM39UwaGJIFWKAE8fS0ak=/v3/t/assets/p19411_p_v12_ah.jpg" style="border-color: #EEEEEE;border-style: solid;border-width: 1px"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2>
#  <a href="https://www.rottentomatoes.com/m/la_confidential">L.A. Confidential</a>
#  <span class="subtle start-year">(1997)</span>
#  <br/>
# ...

# %%
for store in movie_data:  # Correct: for loop header

    name = store.h2.a.text  # Correct: indented
    movie_name.append(name)  # Correct: indented

    year_of_release = store.h2.find('span', class_='subtle start-year').text.replace('(', '').replace(')', '')  # Correct: indented
    year.append(year_of_release)  # Correct: indented

    rate = store.h2.find('img', class_='icon tiny').span.text  # Correct: indented
    rating.append(rate)  # Correct: indented

    critics = store.find('div', class_='info critics-consensus').text.replace('\n', '')  # Correct: indented
    critics_consensus.append(critics)  # Correct: indented

    requirment = store.find('div', class_='info synopsis').text.replace('\n', '')  # Correct: indented
    synopsis.append(requirment)  # Correct: indented

    directer = store.find('div', class_='info director').a.text  # Correct: indented
    director_list.append(directer) #Correct: indented
    
    # ... (rest of your code)

# %%
movie_DF = pd.DataFrame({'Name of movie': movie_name, 
                         'Year of relase': year,
                          'Movie Rating': rating,
                          'Critics': critics_consensus,
                          'synopsis': synopsis,
                         "Director": director_list})

# %%
#Saving data in Excel file:
# !pip install openpyxl
movie_DF.to_excel("Top_100_IMDB_Movies.xlsx")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
movie_DF.head(5)
# Out:
#        Name of movie Year of relase Movie Rating  \
# 0  L.A. Confidential           1997          99%
# 1      The Godfather           1972          97%
# 2         Casablanca           1942          99%
# 3      Seven Samurai           1954         100%
# 4           Parasite           2019          99%
#
#                                              Critics  \
# 0  Critics Consensus: Taut pacing, brilliantly de...
# 1  Critics Consensus: One of Hollywood's greatest...
# 2  Critics Consensus: An undisputed masterpiece a...
# 3  Critics Consensus: Arguably Akira Kurosawa's m...
# 4  Critics Consensus: An urgent, brilliantly laye...
#
#                                             synopsis              Director
# 0  Synopsis: Three policemen, each with his own m...         Curtis Hanson
# 1  Synopsis: Widely regarded as one of the greate...  Francis Ford Coppola
# 2  Synopsis: Rick Blaine (Humphrey Bogart), who o...        Michael Curtiz
# ...
